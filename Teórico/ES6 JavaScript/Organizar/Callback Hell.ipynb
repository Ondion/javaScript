// %% [markdown]
// <h1 style="text-align: center;">Callback Hell</h1>
// <hr>

// %%
a().then(() => {
    b().then(() => {
        c().then(() => {
            d().then(() => {
                e().then(() => {
                    f().then(() => {
                        return HELL!
                    });
                });
            });
        });
    });
});

// %%
a().then(() =>{
    b();
    }).then(() => {
    c();
    }).then(() => {
    d();
    }).then(() => {
    e();
    }).then(() => {
    f();
    }).then(() => {
    return HEAVENS
    });
